# %% [markdown]
# ###   *Projet d'analyse des donnee pour l'entreprise Innova Electronic*

# %% [markdown]
# #### Presente par : *TCHUENKAM Nick*

# %%
#importation des bibliotheques
import numpy as np #pour les operations numeriques
import pandas as pd #pour la manipulation des donnees tabulaires
import matplotlib.pyplot as plt #pour la visualisation des donnees

# %%
#chargement des donnees
donnees = pd.read_csv("ventes-data.csv", sep = ",")

# %%
#affichage des donnees
print(donnees)
# Out:
#         Month           Product  Units Sold  Revenue
# 0     January        Smartphone        1000    50000
# 1     January            Laptop         500   100000
# 2     January            Tablet         300    45000
# 3     January          Smart TV         200    25000
# 4     January        Headphones         800    32000
# ..        ...               ...         ...      ...
# 583  December   Graphics Tablet         315    15750
# 584  December    Ink Cartridges         525    26250
# 585  December      Laptop Stand         210    10500
# 586  December  Portable Scanner         315    15750
# 587  December    Screen Cleaner         420     6300
#
# [588 rows x 4 columns]

# %% [markdown]
# ## Explorations des données pour comprendre leur structure et leur contenu.

# %%
# Obtenir des informations sur les donnees
print(donnees.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       588 non-null    object
#  1   Product     588 non-null    object
#  2   Units Sold  588 non-null    int64
#  3   Revenue     588 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 18.5+ KB
# None

# %% [markdown]
# INTERPRETATION : Notre dataFrame comporte 588 lignes (de 0 a 587) et 4 colonnes (de 0 a 3: Month, Product, Units Sold, Revenue).
# Nature de "Month" et "Product" sont des objects (chaines de caracteres) et  "Units Sold" et "Revenue" sont des int64 (reels).
# Il n'ya aucune valeur manquantes. Pour plus de verification, on a :

# %%
# Obtenir une statistiquqe descriptive pour chaque collonne numerique
print(donnees.describe())
# Out:
#         Units Sold        Revenue
# count   588.000000     588.000000
# mean    489.673469   31221.428571
# std     343.815948   27426.671012
# min     100.000000    3000.000000
# 25%     255.000000   12400.000000
# 50%     382.500000   24000.000000
# 75%     600.000000   41337.500000
# max    2100.000000  210000.000000

# %%
# Verifier si une colonne  a des y'a valeurs manquantes 
print(donnees.isnull().sum()) #ou alors "isna()"
# Out:
# Month         0
# Product       0
# Units Sold    0
# Revenue       0
# dtype: int64

# %% [markdown]
# CONCLUSION : Le DataFrame ne contient pas de donnees manquantes

# %% [markdown]
# ## Analyse des donnees

# %% [markdown]
# **Calcul des ventes totales pour chaque mois.**

# %%
#Calcul des ventes par mois.
ventes_mensuelles = donnees.groupby("Month")[["Revenue"]].sum().sort_values(["Revenue"]) #grouper les mois et calculer les ventes totales
print(ventes_mensuelles)

#Generation du graphique
ventes_mensuelles = ventes_mensuelles.reset_index()
plt.pie(ventes_mensuelles['Revenue'],labels=ventes_mensuelles['Month'], autopct='%.2f%%')
plt.show()
# Out:
#            Revenue
# Month
# January     987000
# February   1085700
# March      1184400
# April      1283100
# May        1381800
# June       1480500
# July       1579200
# August     1677900
# September  1776600
# October    1875300
# November   1974000
# December   2072700

# %% [markdown]
# **Evolution des ventes dans le temps**

# %%
# ventes par mois
mois = ventes_mensuelles["Month"].tolist() 
vente =  ventes_mensuelles["Revenue"].tolist()
plt.plot(mois, vente, c="pink", lw = 4, marker = "o", ms = 7, mec = "black", mfc = "red") 
#c = couleur de la ligne, lw = epaisseur de la ligne
#ms = taille du marqueur, mec = contour du marqueur, mfc= couleur du marqueur les 1eres lettres des couleurs en anglais ou alors on ecrit la couleur entiere

plt.title("Ventes Par Mois", fontweight = "bold", c = "green") #titre du graphique
plt.xlabel("Mois")
plt.ylabel("Revenus")
plt.xticks(rotation = 60, ha = "right")
plt.grid() #mettre une grille
plt.show()

# %%
# ventes par mois

mois = ventes_mensuelles["Month"].tolist() 
vente =  ventes_mensuelles["Revenue"].tolist()

#Generation du graphique.
plt.figure(figsize = (14,7))
plt.bar(mois,vente, color='green')

# Generation des revenus totaux sur les barres
for i, revenu in enumerate(vente):
    plt.text(i, revenu, str(revenu), ha='center', va='bottom',weight='bold')

plt.title("Revenus des Ventes Par Mois", fontweight = "bold", color = "red", size = 20)
plt.xlabel("Mois", fontweight = "bold", size = 15)
plt.ylabel("Revenus",  fontweight = "bold", size = 15)
plt.xticks(rotation = 30, ha = "right")
plt.show()

# %% [markdown]
# **Identification des 5 produits les plus vendus chaque mois.**

# %%
#inserer la colonne quantite a la position voulu
donnees.insert(loc = 3, column = "Quantite", value = (donnees["Revenue"]/donnees["Units Sold"]))

# %%
#affichage des donnees
donnees
# Out:
#         Month           Product  Units Sold  Quantite  Revenue
# 0     January        Smartphone        1000      50.0    50000
# 1     January            Laptop         500     200.0   100000
# 2     January            Tablet         300     150.0    45000
# 3     January          Smart TV         200     125.0    25000
# 4     January        Headphones         800      40.0    32000
# ..        ...               ...         ...       ...      ...
# 583  December   Graphics Tablet         315      50.0    15750
# 584  December    Ink Cartridges         525      50.0    26250
# 585  December      Laptop Stand         210      50.0    10500
# 586  December  Portable Scanner         315      50.0    15750
# 587  December    Screen Cleaner         420      15.0     6300
#
# [588 rows x 5 columns]

# %%
#Identification des 5 produits les plus vendus chaque mois.

Nbre_ventes_mensuelles_par_produit = donnees.groupby(["Month", "Product"]) #grouper les ventes par mois et produits.
Nbre_ventes_mensuelles_par_produit = Nbre_ventes_mensuelles_par_produit["Quantite"].sum() #nbre de ventes par mois et produits.

top5_produit_par_mois = Nbre_ventes_mensuelles_par_produit.groupby("Month", group_keys = False).nlargest(5)
print(top5_produit_par_mois)

#Generation du graphe des top5 par mois

top5_produit_par_mois.unstack().plot(kind="bar", stacked=False, figsize=(15, 8))
plt.xlabel("Mois", size = 14)
plt.ylabel("Quantite", size = 14)
plt.title("Produits les plus vendu par mois", size = 14, weight = "bold")
plt.legend(title = "Produits")
plt.show()
# Out:
# Month      Product
# April      VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# August     VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# December   VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# February   VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# January    VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# July       VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# June       VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# March      VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# May        VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# November   VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# October    VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# September  VR Headset        250.0
#            Drone             200.0
#            Laptop            200.0
#            Smart Home Hub    200.0
#            Game Console      150.0
# Name: Quantite, dtype: float64

# %% [markdown]
# **Mois avec les ventes les plus élevées et les plus basses**

# %%
# Mois avec les ventes les plus élevées.
print(ventes_mensuelles)
# Out:
#         Month  Revenue
# 0     January   987000
# 1    February  1085700
# 2       March  1184400
# 3       April  1283100
# 4         May  1381800
# 5        June  1480500
# 6        July  1579200
# 7      August  1677900
# 8   September  1776600
# 9     October  1875300
# 10   November  1974000
# 11   December  2072700

# %%
mois_max_ventes = ventes_mensuelles.max()
mois_min_ventes = ventes_mensuelles.min()
print("Le mois avec les ventes les plus elevees est : ", mois_max_ventes)
print("Le mois avec les ventes les plus elevees est : ", mois_min_ventes)
# Out:
# Le mois avec les ventes les plus elevees est :  Month      September
# Revenue      2072700
# dtype: object
# Le mois avec les ventes les plus elevees est :  Month       April
# Revenue    987000
# dtype: object

# %%
# Nombres de ventes par mois
ventes_par_mois = donnees.groupby("Month")["Quantite"].sum().nlargest(10)
print(ventes_par_mois)
ventes_par_mois.plot(kind="bar", color= "gold") 
plt.title("Ventes par mois", fontweight = "bold", color = "green")
plt.xlabel("Mois")
plt.ylabel("Quantite")
plt.show()
# Out:
# Month
# April       3630.0
# August      3630.0
# December    3630.0
# February    3630.0
# January     3630.0
# July        3630.0
# June        3630.0
# March       3630.0
# May         3630.0
# November    3630.0
# Name: Quantite, dtype: float64

# %%
# Produits les Plus vendus
produits_plus_vendus = donnees.groupby("Product")["Quantite"].sum().nlargest(10)
print(produits_plus_vendus)
produits_plus_vendus.plot(kind="bar", color= "blue", figsize=(10, 6)) 
plt.title("produits_plus_vendus", fontweight = "bold", color = "green")
plt.xlabel("Produits")
plt.ylabel("Quantite")
plt.show()
# Out:
# Product
# VR Headset        3000.0
# Drone             2400.0
# Laptop            2400.0
# Smart Home Hub    2400.0
# Game Console      1800.0
# Graphics Card     1800.0
# Laser Printer     1800.0
# Tablet            1800.0
# Smart TV          1500.0
# Network Switch    1200.0
# Name: Quantite, dtype: float64

# %% [markdown]
# ### Tendances des ventes des produits les plus vendus

# %% [markdown]
# **Calcul des ventes totales pour chaque produit.**

# %%
# Chargement des Produits les Plus vendus
Qte_produits_vendu = donnees.groupby(["Product"])[["Quantite"]].sum().sort_values(["Quantite"]) #grouper les produits et calculer le total des ventes
print(Qte_produits_vendu)
#Generation du graphe des ventes par Produits
Qte_produits_vendu.plot(kind="bar", color= "green",figsize=(10, 6))
plt.title("Ventes Par Produits", fontweight = "bold", color = "red")
plt.xlabel("Produits")
plt.ylabel("Quantite")
plt.grid(axis="y") #mettre une grille horizontale
plt.tight_layout()  # Ajuster la mise en page pour éviter les chevauchements
plt.show()
# Out:
#                      Quantite
# Product
# USB Cable               120.0
# Screen Cleaner          180.0
# HDMI Cable              180.0
# Power Strip             180.0
# Keyboard                240.0
# USB Flash Drive         240.0
# Mouse                   240.0
# SD Card                 240.0
# Power Bank              360.0
# Bluetooth Adapter       360.0
# Car Charger             360.0
# Headphones              480.0
# Webcam                  540.0
# Portable Scanner        600.0
# Smartphone              600.0
# Wireless Earbuds        600.0
# Wi-Fi Extender          600.0
# Microphone              600.0
# Action Camera           600.0
# Laptop Stand            600.0
# Battery Charger         600.0
# Ink Cartridges          600.0
# Gaming Mouse            600.0
# Compact Camera          600.0
# Graphics Tablet         600.0
# Wireless Speaker        720.0
# Monitor                 720.0
# Smartwatch              720.0
# Wireless Mouse          720.0
# Surge Protector         720.0
# Router                  720.0
# Mechanical Keyboard     840.0
# Smart Thermostat        900.0
# RAM                     960.0
# Printer                 960.0
# External Hard Drive     960.0
# Projector              1200.0
# Processor              1200.0
# Network Switch         1200.0
# SSD                    1200.0
# Smart TV               1500.0
# Laser Printer          1800.0
# Tablet                 1800.0
# Game Console           1800.0
# Graphics Card          1800.0
# Drone                  2400.0
# Smart Home Hub         2400.0
# Laptop                 2400.0
# VR Headset             3000.0

# %%
# Chargement des Produits les Plus vendus
produits_plus_rentables =  donnees.groupby("Product")["Revenue"].sum().nlargest(10) #grouper les produits et calculer le total des ventes
print(produits_plus_rentables)

#Generation du graphique
produits_plus_rentables.plot(kind="bar", color= "pink", figsize=(10, 6)) 
plt.title("produits_plus_rentables", fontweight = "bold", color = "green")
plt.xlabel("Produits")
plt.ylabel("Revenus")
plt.show()
# Out:
# Product
# Laptop              1860000
# Smartphone           930000
# Tablet               837000
# Monitor              781200
# Processor            744000
# Smart Home Hub       744000
# Game Console         697500
# Wireless Speaker     669600
# Headphones           595200
# Drone                558000
# Name: Revenue, dtype: int64

# %%
#Identification des 5 produits les plus vendus chaque mois.

Revenu_mensuel_par_produit = donnees.groupby(["Month", "Product"]) #grouper les ventes par mois et produits.
Revenu_mensuel_par_produit = Revenu_mensuel_par_produit["Revenue"].sum() #Revenu mensuel par mois et produits.

top5_ventes_par_mois = Revenu_mensuel_par_produit.groupby("Month", group_keys = False).nlargest(5)
print(top5_ventes_par_mois)

#Generation du graphe des top5 par mois

top5_ventes_par_mois.unstack().plot(kind="bar", stacked=False, figsize=(15, 8))
plt.xlabel("Mois", size = 14)
plt.ylabel("Revenus", size = 14)
plt.title("Produits les plus rentable par mois", size = 18, weight = "bold", color = "green")
plt.legend(title = "Produits")
plt.show()
# Out:
# Month      Product
# April      Laptop        130000
#            Smartphone     65000
#            Tablet         58500
#            Monitor        54600
#            Processor      52000
# August     Laptop        170000
#            Smartphone     85000
#            Tablet         76500
#            Monitor        71400
#            Processor      68000
# December   Laptop        210000
#            Smartphone    105000
#            Tablet         94500
#            Monitor        88200
#            Processor      84000
# February   Laptop        110000
#            Smartphone     55000
#            Tablet         49500
#            Monitor        46200
#            Processor      44000
# January    Laptop        100000
#            Smartphone     50000
#            Tablet         45000
#            Monitor        42000
#            Processor      40000
# July       Laptop        160000
#            Smartphone     80000
#            Tablet         72000
#            Monitor        67200
#            Processor      64000
# June       Laptop        150000
#            Smartphone     75000
#            Tablet         67500
#            Monitor        63000
#            Processor      60000
# March      Laptop        120000
#            Smartphone     60000
#            Tablet         54000
#            Monitor        50400
#            Processor      48000
# May        Laptop        140000
#            Smartphone     70000
#            Tablet         63000
#            Monitor        58800
#            Processor      56000
# November   Laptop        200000
#            Smartphone    100000
#            Tablet         90000
#            Monitor        84000
#            Processor      80000
# October    Laptop        190000
#            Smartphone     95000
#            Tablet         85500
#            Monitor        79800
#            Processor      76000
# September  Laptop        180000
#            Smartphone     90000
#            Tablet         81000
#            Monitor        75600
#            Processor      72000
# Name: Revenue, dtype: int64
